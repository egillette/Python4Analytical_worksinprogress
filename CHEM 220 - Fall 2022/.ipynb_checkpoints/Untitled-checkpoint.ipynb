# %% [markdown]
# # Slice and Dice ICP data
#
# Using Pandas to import these csv files and then organize by element name and wavelength

# %%
# This is a strategy for importing data into lists so that we can use it!
import numpy as np
import scipy.stats as stats
import pandas as pd
import math
# read the whole data file in:
data = pd.read_csv("Eucalyptus 0.1 ppm 9-6-22.csv", header = 6)


# read all elements and wavelengths in the file:
elements = data.Element.unique()
print(F'These are all the elements and wavelengths that appear in the data file {elements}')

standards =[]
conc = []

#slice by element - all standards data
for x in elements:
    if x != "Ar 430.010":
        temp = data[data.values == x]
        temps = temp[temp.values == 'STD']
        temps_Int = temps['Intensity'].tolist()
        temps_conc = temps['Concentration'].tolist()
        #temps_conc = [float(j) for j in temps_conc]
        standards.append (temps_Int)
    #conc.append(temps_conc)
    
#standards = np.array(standards, dtype = float)
print(F'These are all the standard intensities for each element {standards}')
#print (F'These are the concentrations for each element standard, as recorded in the file {conc}')
                            
sample = []
#slice by element - all sample data
for x in elements:
    temp = data[data.values == x]
    temps = temp[temp.values == 'Sample']
    temps_Int = temps['Intensity'].tolist()
    
    sample.append (temps_Int)

#print (sample)
# Out:
# These are all the elements and wavelengths that appear in the data file ['Ag 328.068' 'Al 237.312' 'Al 396.152' 'Ar 430.010' 'As 188.980'
#  'Ba 455.403' 'Be 234.861' 'Be 313.042' 'Ca 317.933' 'Ca 396.847'
#  'Cd 214.439' 'Co 238.892' 'Cr 267.716' 'Cu 327.395' 'Fe 238.204'
#  'K 766.491' 'Mg 279.553' 'Mg 279.800' 'Mg 285.213' 'Mn 257.610'
#  'Mo 202.032' 'Na 588.995' 'Na 589.592' 'Ni 231.604' 'Pb 220.353'
#  'Sb 206.834' 'Se 196.026' 'Th 283.730' 'Th 288.505' 'Tl 190.794'
#  'Tl 351.923' 'U 385.957' 'V 292.401' 'Zn 206.200' 'Zn 213.857']
# These are all the standard intensities for each element [['1017.6563', '3040.1117', '5823.1259', '11228.846', '22285.635', '55741.3941', '1097.5347', '3131.4904', '5950.7967', '11613.2355', '22816.7625', '57326.8418', '1050.7687', '3173.7944', '6064.4242', '11864.4351', '23176.8318', '58203.5483', '1134.2365', '3127.2711', '6004.07', '11779.7928', '23216.8785', '57793.8597'], ['55.1769', '81.1419', '145.9584', '233.0347', '434.8637', '1075.3223', '51.2727', '82.9275', '131.6641', '252.1433', '474.6275', '1124.5601', '52.0172', '73.1142', '150.3778', '252.1953', '470.152', '1158.6384', '57.0926', '85.0429', '140.9915', '249.6012', '486.5681', '1123.8405'], ['-', '1664.1867', '2951.7475', '5314.8389', '10089.9514', '24830.7565', '-', '1729.7433', '3060.2037', '5525.8534', '10516.0472', '25655.4823', '-', '1743.2455', '3120.6244', '5602.3581', '10597.7425', '26002.5642', '-', '1718.709', '3122.1118', '5299.8392', '10655.633', '25865.5507'], ['-', '100.9415', '164.0215', '322.3925', '644.9748', '1606.2374', '-', '108.3571', '178.8479', '344.6504', '681.8675', '1671.3304', '-', '106.3102', '181.7481', '343.0203', '682.5124', '1707.7904', '-', '110.5573', '179.5628', '342.3069', '688.2486', '1688.6727'], ['-', '12598.9821', '24686.9607', '48139.5426', '96630.124', '237489.1434', '-', '13472.7946', '26486.5809', '51567.6395', '101944.0234', '251221.7623', '-', '13727.5113', '-', '-', '102691.655', '254027.8051', '6341.7591', '13694.4679', '26584.5877', '51913.0127', '103865.3496', '254314.9655'], ['1501.8879', '3994.2391', '7850.8802', '15618.4029', '31391.2975', '77677.8992', '1587.9148', '4191.4479', '8268.3313', '16468.1644', '32693.7152', '81003.7351', '1604.7589', '4270.7059', '8400.309', '-', '33193.1097', '82134.2331', '1631.9695', '4307.3302', '8462.6491', '16836.2223', '33632.4801', '83372.374'], ['7205.8374', '19673.7734', '38612.0657', '76730.6328', '154622.7891', '379997.9965', '7620.8021', '20724.8631', '40867.3447', '81119.0503', '161092.4183', '396975.4604', '7700.8684', '21132.215', '41494.7408', '-', '163079.2495', '402727.7705', '7919.5849', '21292.0031', '41592.6542', '82661.0269', '165360.113', '407668.3827'], ['10545.4346', '20860.9654', '40304.3242', '78517.0311', '156161.2742', '383119.0865', '-', '21209.2899', '41251.2652', '80389.4894', '158434.4485', '389613.4783', '10761.5262', '21465.9515', '41696.9105', '-', '159766.6721', '393140.4443', '9775.9994', '21588.5967', '42034.197', '81111.4304', '165388.7076', '398255.9948'], ['1168392.078', '2298187.208', '4452244.952', '8569802.09', '16808288.28', '####', '-', '2472582.323', '4799552', '9224300.569', '17790307.41', '####', '1285334.181', '2523920.143', '4883171.896', '-', '18006791.15', '####', '1156562.875', '2524538.906', '4870814.09', '9332293.472', '18560999.73', '####'], ['2080.2928', '5537.5597', '10928.4496', '21583.367', '42637.7055', '104948.3366', '2137.8498', '5669.3418', '11133.0417', '22047.7356', '43348.6466', '106529.1466', '2158.8018', '5716.5336', '11252.2539', '22421.6377', '43764.7754', '107897.1313', '2179.051', '5736.768', '11266.5953', '22358.2315', '44200.7805', '108150.1332'], ['7221.1857', '18478.8098', '36027.8635', '71172.9025', '140069.1375', '353779.5031', '7678.3395', '19166.3584', '36700.0306', '71828.2806', '144264.0335', '353080.0627', '7197.4257', '18351.1462', '35550.2319', '71192.6971', '136316.7238', '338989.5241', '5607.6097', '13935.4093', '27227.1355', '54246.8607', '103872.2912', '259211.5197'], ['1125.1429', '2952.5147', '5830.1476', '11300.5097', '22524.918', '55606.2153', '1174.6551', '3031.2467', '5988.7598', '11651.0839', '23137.0581', '56812.2447', '1173.2776', '3064.9143', '6062.7522', '11845.8566', '23414.3385', '57605.7762', '1161.3043', '3019.2028', '6057.0295', '11649.44', '23212.5747', '56974.8754'], ['-', '-', '3599.0532', '6627.3783', '13090.6476', '32100.5609', '-', '-', '3743.2121', '6885.0634', '13600.8357', '33023.1724', '-', '-', '3772.2401', '7025.754', '13743.9681', '33567.0587', '2346.0596', '351 ...

# %%
import matplotlib.pyplot as plt
conc = [0.01,0.025,0.05,0.1,0.2,0.5]
x = np.array(conc)
y = np.array(standards)

for i in range(len(elements)):
    #plt.plot(x, y[i])
    plt.plot(x[i], y[i,0:len(x)], 'rx')
plt.show()

#plt.errorbar(x.T, y.T, yerr = None, xerr = None, fmt = 'r.')
#plt.xlabel("concentration (ug/L)")
#plt.ylabel("average intensity")
# Out:
# C:\Users\egillette\AppData\Local\Temp\ipykernel_12488\2360331414.py:4: VisibleDeprecationWarning: Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray.
#   y = np.array(standards)
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# Input In [40], in <cell line: 6>()
#       4 y = np.array(standards)
#       6 for i in range(len(elements)):
#       7     #plt.plot(x, y[i])
# ----> 8     plt.plot(x[i], y[i,0:len(x)], 'rx')
#       9 plt.show()
#
# IndexError: too many indices for array: array is 1-dimensional, but 2 were indexed
