# %% [markdown]
# # Slice and Dice ICP data
#
# Using Pandas to import these csv files and then organize by element name and wavelength
#
# ### Currently working - as of 11/2/2022 at ~ 2pm
# Updates made -
# * samples now organized and plotted appropriately
# * standard deviations and error bars need to be added to all plots
# * waiting for updates on equilbrium concentration choices
#
# ### 12/6/2022 updates
# * Scipy curve fit has been added, currently fitting a general exponential function of format $ a  (e^{-cx}) + d $
# * Comments and explanations of the process have been expanded

# %% [markdown]
# ## Part 1 - Reading and Organizing the data
#
# This section reads in the csv file, sorts each line by element and whether or not it is a standard or a sample. Currently all other data types (QC etc are ignored). Argon is removed from the elements list and data lists in this block as well. Current output is just confirming all of the unique elements identified in the file, and giving the standard values for the first element, as a place to double check that the code is working.

# %%
# This is a strategy for importing data into lists so that we can use it!
import numpy as np
import scipy.stats as stats
import pandas as pd
import math
# read the whole data file in:
data = pd.read_csv("Eucalyptus 0.1 ppm 9-6-22.csv", header = 6)


# read all elements and wavelengths in the file:
elements = data.Element.unique()
print(F'These are all the elements and wavelengths that appear in the data file {elements}')

standards =[]
conc = []

#slice by element - all standards data, exclusing argons, since it's always weird?

for x in elements:
    if x != "Ar 430.010":
        temp = data[data.values == x]
        temps = temp[temp.values == 'STD']
        #grab all intensity values
        #remove nonsense - what do you actually want me to do here?
        temps_Int = temps['Intensity'].replace(['-','####'], 0)
        #convert to list
        list_int = temps_Int.tolist()
        #make sure all values are actually numbers
        list_int = [float(j) for j in list_int]
        #add this list to the end of the existing list of standard intensities
        standards.append (list_int)
        
        #grab concentration values
        #remove nonsense - what do you actually want me to do here?
        temps_conc = temps['Concentration'].replace(['-','####','--'], 0)
        # convert to list
        list_conc = temps_conc.tolist()
        # make sure all list digits are numbers
        list_conc = [float(j) for j in list_conc]
        #add to the end of exisiting list of concentrations
        conc.append(list_conc)
    
#show one example to check values
print(F'These are all the standard intensities for {elements[0]} are {standards[0]}')
print (F'These are the concentrations for {elements[0]}, as recorded in the file {conc[0]}')


#repeat for samples instead of standards
sample = []
sample_label = []


#slice by element - all sample data
for x in elements:
    if x != "Ar 430.010":
        temp = data[data.values == x]
        temps = temp[temp.values == 'Sample']
        temps_clean = temps['Intensity'].replace(['-','####'], 0)
        
        temps_Int = temps_clean.tolist()
        
        #make sure all values are actually numbers
        temps_Int = [float(j) for j in temps_Int]
    
        sample.append (temps_Int)
        
        #repeat to get sample labels
        temp = data[data.values == x]
        temps = temp[temp.values == 'Sample']
        temps_label = temps['Label'].tolist()
    
        sample_label.append (temps_label)

        
#why is Zn 216 not working? ALL LABELS ARE OFF BY ONE, BECAUSE OF ARGON :-(

#quick and dirty solution - remove argon from the list

elements = np.delete(elements, 3)

#print(F'All of the samples for {elements[0]} are {sample_label[0]} with values of {sample[0]}')
# Out:
# These are all the elements and wavelengths that appear in the data file ['Ag 328.068' 'Al 237.312' 'Al 396.152' 'Ar 430.010' 'As 188.980'
#  'Ba 455.403' 'Be 234.861' 'Be 313.042' 'Ca 317.933' 'Ca 396.847'
#  'Cd 214.439' 'Co 238.892' 'Cr 267.716' 'Cu 327.395' 'Fe 238.204'
#  'K 766.491' 'Mg 279.553' 'Mg 279.800' 'Mg 285.213' 'Mn 257.610'
#  'Mo 202.032' 'Na 588.995' 'Na 589.592' 'Ni 231.604' 'Pb 220.353'
#  'Sb 206.834' 'Se 196.026' 'Th 283.730' 'Th 288.505' 'Tl 190.794'
#  'Tl 351.923' 'U 385.957' 'V 292.401' 'Zn 206.200' 'Zn 213.857']
# These are all the standard intensities for Ag 328.068 are [1017.6563, 3040.1117, 5823.1259, 11228.846, 22285.635, 55741.3941, 1097.5347, 3131.4904, 5950.7967, 11613.2355, 22816.7625, 57326.8418, 1050.7687, 3173.7944, 6064.4242, 11864.4351, 23176.8318, 58203.5483, 1134.2365, 3127.2711, 6004.07, 11779.7928, 23216.8785, 57793.8597]
# These are the concentrations for Ag 328.068, as recorded in the file [0.01, 0.025, 0.05, 0.1, 0.2, 0.5, 0.01, 0.025, 0.05, 0.1, 0.2, 0.5, 0.01, 0.025, 0.05, 0.1, 0.2, 0.5, 0.01, 0.025, 0.05, 0.1, 0.2, 0.5]

# %% [markdown]
# ## Standard Curve Fitting
# All standards data are processed here, linear regressions applied, and best-fit lines added to graphs, with equations of the line output above the relevent standard curve.
#
# <b> Still pending </b>
# * I need to add the grouping/averaging and standard deviation/error bars to these plots,
# * I can add an option to output these files as images if needed

# %%
import matplotlib.pyplot as plt



x = np.array(conc, dtype = object)
y = np.array(standards, dtype = object)

#empty space for unknown concentrations

unknowns = []


for i in range(len(elements)):
    m, b, R2, p, s_m = stats.linregress(x[i], y[i])
    
    # solve for unknown_concentration
    unknown_y = np.array(sample[i])
    unknown_concentration = (unknown_y-b)/m
    unknowns.append(unknown_concentration)

    print (F'the equation of the line for {elements[i]} is y = {m}x + {b} and its R-squared value is {R2}')
    # Use our predicted model
    x_predict = np.array(x[i])
    predict_y = (x_predict*m)+b
    # Plot the predicted data (note if we don't ask for a specific marker style, we'll just get a line)
    plt.plot(x[i],predict_y)
    plt.plot(x[i], y[i], 'rx')
    
    plt.xlabel(F'concentration of {elements[i]}')
    plt.ylabel(F'intensity of {elements[i]}')
    plt.show()
    

    

#plt.errorbar(x.T, y.T, yerr = None, xerr = None, fmt = 'r.')
#plt.xlabel("concentration (ug/L)")
#plt.ylabel("average intensity")
# Out:
# the equation of the line for Ag 328.068 is y = 114219.71920557362x + 138.56398801122486 and its R-squared value is 0.9997406976691243
# the equation of the line for Al 237.312 is y = 2181.018166485703x + 30.06335377669211 and its R-squared value is 0.9991356804608197
# the equation of the line for Al 396.152 is y = 50590.158347181x + 333.4014618694364 and its R-squared value is 0.9995023000482689
# the equation of the line for As 188.980 is y = 3317.0945667655783x + 10.188321513353117 and its R-squared value is 0.9994314908509034
# the equation of the line for Ba 455.403 is y = 497749.68144100317x + 789.9890732595668 and its R-squared value is 0.9993337036595208
# the equation of the line for Be 234.861 is y = 162037.81002418403x + 111.83295070028908 and its R-squared value is 0.9994062384282834
# the equation of the line for Be 313.042 is y = 793437.7606832586x + 768.5727520662476 and its R-squared value is 0.9993925031956066
# the equation of the line for Ca 317.933 is y = 7791.454315065227x + 2205.153655526112 and its R-squared value is 0.999767445669197
# the equation of the line for Ca 396.847 is y = 883413.5036012117x + 183331.34741778113 and its R-squared value is 0.9986435791151229
# the equation of the line for Cd 214.439 is y = 213299.34148063694x + 441.85406910605525 and its R-squared value is 0.999834621259013
# the equation of the line for Co 238.892 is y = 650354.785702859x + 1204.547537994964 and its R-squared value is 0.987468616065213
# the equation of the line for Cr 267.716 is y = 113219.7780716612x + 232.40934276330518 and its R-squared value is 0.9998223971402238
# the equation of the line for Cu 327.395 is y = 65273.613452029545x + 402.6269735366677 and its R-squared value is 0.9989281411430417
# the equation of the line for Fe 238.204 is y = 103734.41158463989x + 48053.11708489456 and its R-squared value is 0.999615123213293
# the equation of the line for K 766.491 is y = 62573.34927602816x + -56371.19447849272 and its R-squared value is 0.9985274581103334
# the equation of the line for Mg 279.553 is y = 297397.7795737544x + 333220.1545136869 and its R-squared value is 0.9984956015418367
# the equation of the line for Mg 279.800 is y = 1338.4204028011268x + 157.0716431838482 and its R-squared value is 0.9998476660529793
# the equation of the line for Mg 285.213 is y = 14066.759529957739x + 3519.6044206056977 and its R-squared value is 0.9995972079429966
# the equation of the line for Mn 257.610 is y = 586568.9971766195x + 1598.5313789486245 and its R-squared value is 0.9997347700922212
# the equation of the line for Mo 202.032 is y = 37450.94849511399x + 45.6997969706872 and its R-squared value is 0.9997841211534451
# the equation of the line for Na 588.995 is y = 418876.67384040856x + 158411.1030041445 and its R-squared value is 0.999175020458533
# the equation of the line for Na 589.592 is y = 240360.3672481334x + -148479.99444824597 and its R-squared value is 0.9993963857751681
# the equation of the line for Ni 231.604 is y = 43282.64766811436x + 176.7820231197984 and its R-squared value is 0.9998548960477526
# the equation of the line for Pb 220.353 is y = 9842.507288106064x + 53.10742804106644 and its R-squared value is 0.9997770127010288
# the equation of the line for Sb 206.834 is y = 3205.9642397409634x + 11.582043071433304 and its R-squared value is 0.9998395082958248
# the equation of the line for Se 196.026 is y = 2336.5002956930866x + 9.602818885269755 and its R-squared value is 0.9998685856146453
# the equation of the line for Th 283.730 is y = 21068.27722421838x + 19.623439291395698 and its R-squared value is 0.9998219090991878
# the equation of the line for Th 288.505 is y = 5937.493987767584x + 97.5677434250764 and its R-squared value is 0.9977793066929727
# the equation of the line for Tl 190.794 is y = 2895.670056460368x + 1.0708500054290653 and its R-squared value is 0.9997000849632205
# the equation of the line for Tl 351.923 is y = 4779.207657566764x + 37.48642077151351 and its R-squared value is 0.9993209550263568
# the equation of the line for U 385.957 is y = 546914.2536667609x + -1838.1858643194137 and its R-squared value is 0.9995718577169469
# the equation of the line for V 292.401 is y = 44342.12852045199x + 102.61077178351934 and its R-squared value is 0.9997515376471969
# the equation of the line for Zn 206.200 is y = 55000.51429936146x + 422.62131352862525 and its R-squared value is 0.9993283279119843
# the equation of the line for Zn 213.857 is y = 116150.817570523x + 1405.855896082936 and its R-squared value is 0.9977589815158598

# %% [markdown]
# ## Part 3
# This block is currently not doing anything; it can be turned back on to produce individual graphs for each sample, if needed

# %%
for x in range(len(elements)):
    #print(F'the concentration of {elements[x]} in these samples')
    label = sample_label[x]
    number = unknowns[x]
    #print(number)
    
    #find the replicates by organizing the list into groups of three
    n = number.reshape(-1,3)
    
    #average replicates (taking the mean of each group of three)
    sample = n.reshape(-1, 3).mean(axis=1)
    #print(sample)
    #reorganize by trial (making 4 groups of 10 numbers)
    all_sample = sample.reshape(-1,10)
    #print(all_sample)
    #print(all_sample)
    
    
    time = [0,15,30,45,60,90,120,240,480,720] #x axis values
    
    #remove hashtags in front of all lines if you want to see graphs for each sample plotted independently
    #currently hidden for clarity
    #for i in range(len(all_sample)):
        #plt.plot(time,all_sample[i], 'r.')
        #plt.xlabel(F'time')
        #plt.ylabel(F'concentration of {elements[x]}')
        #plt.xlim([0, 730])
        
        #plt.show()

# %% [markdown]
# ## Part 4 - Organizing samples by element for all treatments
#
# This block has the graphs of each of the 4 treatments for each element, with a legend. Currently, the x and y axis ranges are locked, so if a graph appears empty, it is because the data does not fall in the y range 0 to 0.11. This can be updated, as desired.

# %%
for x in range(len(elements)):
    print(F'the concentration of {elements[x]} in these samples')
    label = sample_label[x]
    number = unknowns[x]
    #print(number)
    n = number.reshape(-1,3)
    
        
    sample = n.reshape(-1, 3).mean(axis=1)
    
    #add std and error points
    
    #print(sample)
    all_sample = sample.reshape(-1,10)
    #print(all_sample)
    
    #print(all_sample)
    marker = ['rx','bo', 'gv' , 'k*', 'cs']
    
    
    time = [0,15,30,45,60,90,120,240,480,720]
    for i in range(len(all_sample)):
        if all_sample[i,0] > 0 :
            plt.plot(time, all_sample[i], 'o')
            plt.xlabel(F'time')
            plt.ylabel(F'concentration of {elements[x]}')
            plt.xlim([0, 730])
            plt.ylim([0, 0.11]) #set max to just above 0.1, just for consistency
        
        
            #add labels, fix legend
            plt.legend(['HCl', 'HNO3','NaOH', 'Control'])
    plt.show()
# Out:
# the concentration of Ag 328.068 in these samples
# the concentration of Al 237.312 in these samples
# the concentration of Al 396.152 in these samples
# the concentration of As 188.980 in these samples
# the concentration of Ba 455.403 in these samples
# the concentration of Be 234.861 in these samples
# the concentration of Be 313.042 in these samples
# the concentration of Ca 317.933 in these samples
# the concentration of Ca 396.847 in these samples
# the concentration of Cd 214.439 in these samples
# the concentration of Co 238.892 in these samples
# the concentration of Cr 267.716 in these samples
# the concentration of Cu 327.395 in these samples
# the concentration of Fe 238.204 in these samples
# the concentration of K 766.491 in these samples
# the concentration of Mg 279.553 in these samples
# the concentration of Mg 279.800 in these samples
# the concentration of Mg 285.213 in these samples
# the concentration of Mn 257.610 in these samples
# the concentration of Mo 202.032 in these samples
# the concentration of Na 588.995 in these samples
# the concentration of Na 589.592 in these samples
# the concentration of Ni 231.604 in these samples
# the concentration of Pb 220.353 in these samples
# the concentration of Sb 206.834 in these samples
# the concentration of Se 196.026 in these samples
# the concentration of Th 283.730 in these samples
# the concentration of Th 288.505 in these samples
# the concentration of Tl 190.794 in these samples
# the concentration of Tl 351.923 in these samples
# the concentration of U 385.957 in these samples
# the concentration of V 292.401 in these samples
# the concentration of Zn 206.200 in these samples
# the concentration of Zn 213.857 in these samples

# %% [markdown]
# ## playing around with scip polyfit
#
# Curve fitting in enabled here; the data remains organized as above (all treatments graphed together for each element). Best fit lines based on the current curve fitting function are added to the graphs, and the variable from the fit are printed above the graph. Note treatments are in the same order as above, so treatement 0 is HCl, 1 is HNO3, 2 is NaOH and 3 is Control.

# %%
from scipy.optimize import curve_fit
#this is the test function - the variable has to go first followed by as many parameter variables as you will need. Here we use 3, called a c and d (skipping b since it's used above in the linear regressions)
def testfunction(ex,a,c,d):
    return a*np.exp(-c*ex)+d

#data organization as before    
for x in range(len(elements)):
    #print(F'the concentration of {elements[x]} in these samples')
    label = sample_label[x]
    number = unknowns[x]
    n = number.reshape(-1,3)
         
    sample = n.reshape(-1, 3).mean(axis=1)
    all_sample = sample.reshape(-1,10)
     
    
    
    # for curvefit to work, we need the ex variable as a numpy array
    #time is the actual data x axis
    time = np.array([0,15,30,45,60,90,120,240,480,720])
    
    #xx is a list of numbers from 1 to 720 which is used to draw detailed best fit lines
    xx = np.array(list(range(1,720)))
    # an index of colors is used here to make sure markers for the actual data and best fit lines always match in color!
    colors = ['r','k','b','g']
    
    for i in range(len(all_sample)):
        # again, just making things np arrays
        yfit = np.array(all_sample[i])
        #here we apply the curve fit. The format is the model function, the x dat and y data we're trying to fit, the p0 = starting guesses for variables, maxfev= # of iterations allowed before the regression fails
        params, cv = curve_fit(testfunction, time, yfit, p0 = [0.5,0.0025,0.1],maxfev=8000)
        #here we take the best fit parameters the regression determines, and print them out:
        print(F'The fittings paratmers a, c and d are {params} for {elements[x]} treatment number {i}')
        
       #plug the parameters back into the test function with the dummy x data to draw detailed best fit lines
        predict_y = testfunction(xx,*params)
        #plot the real data, with circles
        plt.plot(time, yfit, 'o', color=colors[i%4])
        #plot the best fit line, as a line
        plt.plot(xx,predict_y, color=colors[i%4])
        #axis labes and legends
        plt.xlabel(F'time')
        plt.ylabel(F'concentration of {elements[x]}')
        plt.legend(['HCl', 'HNO3','NaOH', 'Control'])
    plt.show()
# Out:
# The fittings paratmers a, c and d are [ 1.71691219e+01  6.11830450e-07 -1.71207483e+01] for Ag 328.068 treatment number 0
# The fittings paratmers a, c and d are [0.01870982 0.00208468 0.0329583 ] for Ag 328.068 treatment number 1
# The fittings paratmers a, c and d are [0.03082282 0.00556168 0.03124969] for Ag 328.068 treatment number 2
# The fittings paratmers a, c and d are [ 5.70025499e+01  3.98525174e-07 -5.69476470e+01] for Ag 328.068 treatment number 3
# The fittings paratmers a, c and d are [-5.68445877e+01  5.46914067e-07  5.69674177e+01] for Al 237.312 treatment number 0
# The fittings paratmers a, c and d are [ 5.75424498e+00  1.03471403e-06 -5.62254643e+00] for Al 237.312 treatment number 1
# The fittings paratmers a, c and d are [-0.00528505  0.0160183   0.13555597] for Al 237.312 treatment number 2
# The fittings paratmers a, c and d are [-0.01934682  0.03223705  0.13936702] for Al 237.312 treatment number 3
# The fittings paratmers a, c and d are [-6.41204208e+01  5.09212287e-07  6.42510761e+01] for Al 396.152 treatment number 0
# The fittings paratmers a, c and d are [ 7.76339369e+00  1.12786696e-06 -7.62378811e+00] for Al 396.152 treatment number 1
# The fittings paratmers a, c and d are [-7.11675461e-18 -4.80411863e-02  1.42074995e-01] for Al 396.152 treatment number 2
# The fittings paratmers a, c and d are [-9.77959357e+00  1.86769643e-06  9.91934996e+00] for Al 396.152 treatment number 3
# The fittings paratmers a, c and d are [0.10492579 0.01195827 0.13643861] for As 188.980 treatment number 0
# The fittings paratmers a, c and d are [0.01584545 0.0079172  0.10024802] for As 188.980 treatment number 1
# The fittings paratmers a, c and d are [0.00673067 0.01570005 0.08984132] for As 188.980 treatment number 2
# The fittings paratmers a, c and d are [-1.16655469e+03  4.21111966e-07  1.16666868e+03] for As 188.980 treatment number 3
# The fittings paratmers a, c and d are [-0.02107276  0.01015073  0.11610124] for Ba 455.403 treatment number 0
# The fittings paratmers a, c and d are [ 1.77361861e+01  6.92593728e-07 -1.76245973e+01] for Ba 455.403 treatment number 1
# The fittings paratmers a, c and d are [-0.01060215  0.00118365  0.12621895] for Ba 455.403 treatment number 2
# The fittings paratmers a, c and d are [ 8.31030949e+00  3.78262438e-07 -8.19000346e+00] for Ba 455.403 treatment number 3
# The fittings paratmers a, c and d are [-0.01766107  0.00887342  0.09533119] for Be 234.861 treatment number 0
# The fittings paratmers a, c and d are [ 1.86181564e+01  4.82884978e-07 -1.85304263e+01] for Be 234.861 treatment number 1
# The fittings paratmers a, c and d are [-0.00418266  0.00257133  0.09575338] for Be 234.861 treatment number 2
# The fittings paratmers a, c and d are [-0.00149398  0.00791525  0.095451  ] for Be 234.861 treatment number 3
# The fittings paratmers a, c and d are [-0.0178086   0.00900912  0.09472544] for Be 313.042 treatment number 0
# The fittings paratmers a, c and d are [ 1.75118994e+01  5.48838552e-07 -1.74247394e+01] for Be 313.042 treatment number 1
# The fittings paratmers a, c and d are [-0.00413938  0.00180741  0.09523842] for Be 313.042 treatment number 2
# The fittings paratmers a, c and d are [-0.00233998  0.00795155  0.09569154] for Be 313.042 treatment number 3
# The fittings paratmers a, c and d are [ 1.26896266e+04 -1.13775730e-06 -1.26288207e+04] for Ca 317.933 treatment number 0
# The fittings paratmers a, c and d are [ 1.15870981e+04  6.32865438e-07 -1.15218149e+04] for Ca 317.933 treatment number 1
# The fittings paratmers a, c and d are [ 4.39290609e+03 -9.17995983e-07 -4.32367384e+03] for Ca 317.933 treatment number 2
# The fittings paratmers a, c and d are [ 4.20393716e+03 -4.65219776e-07 -4.13314890e+03] for Ca 317.933 treatment number 3
# The fittings paratmers a, c and d are [ 5.64191640e-10  1.18541142e-03 -2.07526087e-01] for Ca 396.847 treatment number 0
# The fittings paratmers a, c and d are [ 5.64191640e-10  1.18541142e-03 -2.07526087e-01] for Ca 396.847 treatment number 1
# The fittings paratmers a, c and d are [ 5.64191640e-10  1.18541142e-03 -2.07526087e-01] for Ca 396.847 treatment number 2
# The fittings paratmers a, c and d are [ 5.64191640e-10  1.18541142e-03 -2.07526087e-01] for Ca 396.847 treatment number 3
# C:\Users\egillette\Anaconda3\lib\site-packages\scipy\optimize\minpack.py:833: OptimizeWarning: Covariance of the parameters could not be estimated
#   warnings.warn('Covariance of the parameters could not be estimated',
# C:\Users\egillette\Anaconda3\lib\site-packages\scipy\optimize\minpack.py:833: OptimizeWarning: Covariance of the parameters could not be estimated
#   warnings.warn('Covariance of the parameters could not be estimated',
# C:\Users\egillette\Anaconda3\lib\site-packages\scipy\optimize\minpack.py:833: OptimizeWarning: Covariance of the parameters could not be estimated
#   warnings.warn('Covariance of the parameters could not be estimated',
# C:\Users\egillette\Anaconda3\lib\site-packages\scipy\optimize\minpack.py:833: OptimizeWarning: Covariance of the parameters could not be estimated
#   warnings.warn('Covariance of the parameters could not be estimated',
# The fittings paratmers a, c and d are [-0.00370375  0.08360236  0.09353359] for Cd 214.439 treatment number 0
# The fittings paratmers a, c and d are [-0.00329562  0.00332881  0.09595942] for Cd 214.439 treatment number 1
# The fittings paratmers a, c and d are [-1.35376284e+00  5.22675469e-07  1.44627100e+00] for Cd 214.439 treatment number 2
# The fittings paratmers a, c and d are [-0.00297506  0.00362689  0.09451991] for Cd 214.439 treatment number 3
# The fittings paratmers a, c and d are [-0.0126731   0.00893107  0.11150679] for Co 238.892 treatment number 0
# The fittings paratmers a, c and d are [0.00556934 0.01058695 0.09611486] for Co 238.892 treatment number 1
# The fittings paratmers a, c and d are [0.02926897 0.01616684 0.06637842] for Co 238.892 treatment number 2
# The fittings paratmers a, c and d are [-0.05004304  0.00054294  0.1140208 ] for Co 238.892 treatment number 3
# The fittings paratmers a, c and d are [-0.00568742  0.01038113  0.09555789] for Cr 267.716 treatment number 0
# The fittings paratmers a, c and d are [-0.00766424  0.00089058  0.09948592] for Cr 267.716 treatment number 1
# The fittings paratmers a, c and d are [-1.15590098e+00  6.15440834e-07  1.24737813e+00] for Cr 267.716 treatment number 2
# The fittings paratmers a, c and d are [-0.01280594  0.00207234  0.10293156] for Cr 267.716 treatment number 3
# The fittings paratmers a, c and d are [0.01986183 0.00628622 0.10913211] for Cu 327.395 treatment number 0
# The fittings paratmers a, c and d are [-0.00579102  0.08921855  0.10834356] for Cu 327.395 treatment number 1
# The fittings paratmers a, c and d are [-5.93419771e+00  1.06542505e-06  6.03737268e+00] for Cu 327.395 treatment number 2
# The fittings paratmers a, c and d are [ 1.19333585e+00  2.94439029e-07 -1.07009844e+00] for Cu 327.395 treatment number 3
# The fittings paratmers a, c and d are [ 4.07467910e+03 -3.52650488e-07 -4.06512569e+03] for Fe 238.204 treatment number 0
# The fittings paratmers a, c and d are [-5.98586945e+01  4.56863667e-07  6.92738741e+01] for Fe 238.204 treatment number 1
# The fittings paratmers a, c and d are [1.75693648 0.01300601 7.81778998] for Fe 238.204 treatment number 2
# The fittings paratmers a, c and d are [ 1.82693709e+04 -4.81766818e-07 -1.82599181e+04] for Fe 238.204 treatment number 3
# The fittings paratmers a, c and d are [ 2.77919658e-15 -5.14809368e-02  6.83756228e+01] for K 766.491 treatment number 0
# The fittings paratmers a, c and d are [ 1.49148646e+04 -8.09890597e-07 -1.48411124e+04] for K 766.491 treatment number 1
# The fittings paratmers a, c and d are [-5.11044091e+01 -7.69175089e-05  7.63952336e+01] for K 766.491 treatment number 2
# The fittings paratmers a, c and d are [-2.46139802e+01 -2.88651275e-06  4.96855591e+01] for K 766.491 treatment number 3
# The fittings paratmers a, c and d are [ 2.04672443e+02 -4.81986582e-07 -1.79142032e+02] for K 766.491 treatment number 4
# The fittings paratmers a, c and d are [ 2.40071448e+03 -6.63908784e-07 -2.37514941e+03] for K 766.491 treatment number 5
# The fittings paratmers a, c and d are [ 1.24621283e+04 -5.23764157e-07 -1.24346895e+04] for K 766.491 treatment number 6
# The fittings paratmers a, c and d are [ 5.12321157e+02  4.08848207e-07 -4.81881264e+02] for K 766.491 treatment number 7
# The fittings paratmers a, c and d are [ 7.59071844e+03 -7.19530390e-07 -7.56669554e+03] for Mg 279.553 treatment number 0
# The fittings paratmers a, c and d are [ 5.97723454e+03  4.23885808e-07 -5.95150225e+03] for Mg 279.553 treatment number 1
# The fittings paratmers a, c and d are [ 2.27028002e+03 -7.20638161e-07 -2.24289976e+03] for Mg 279.553 treatment number 2
# The fittings paratmers a, c and d are [ 1.92229770e+03 -3.67045884e-07 -1.89444591e+03] for Mg 279.553 treatment number 3
# The fittings paratmers a, c and d are [ 4.12761730e+03 -1.26463849e-06 -4.10491939e+03] for Mg 279.800 treatment number 0
# The fittings paratmers a, c and d are [ 4.78117299e+03  5.68334341e-07 -4.75683160e+03] for Mg 279.800 treatment number 1
# The fittings paratmers a, c and d are [ 2.18883854e+03 -8.37903208e-07 -2.16293577e+03] for Mg 279.800 treatment number 2
# The fittings paratmers a, c and d are [ 1.48593527e+03 -3.79027213e-07 -1.45939682e+03] for Mg 279.800 treatment number 3
# The fittings paratmers a, c and d are [ 5.94233870e+03 -9.31129218e-07 -5.91938466e+03] for Mg 285.213 treatment number 0
# The fittings paratmers a, c and d are [ 6.56626607e+03  4.27396367e-07 -6.54145961e+03] for Mg 285.213 treatment number 1
# The fittings paratmers a, c and d are [ 2.07453300e+03 -9.38050625e-07 -2.04818375e+03] for Mg 285.213 treatment number 2
# The fittings paratmers a, c and d are [ 7.70530221e+02 -4.52152608e-07 -7.43457996e+02] for Mg 285.213 treatment number 3
# The fittings paratmers a, c and d are [-0.01736422  0.01495859  0.10864631] for Mn 257.610 treatment number 0
# The fittings paratmers a, c and d are [-0.00700289  0.00130449  0.10120844] for Mn 257.610 treatment number 1
# The fittings paratmers a, c and d are [-0.08024095  0.18765246  0.17435174] for Mn 257.610 treatment number 2
# The fittings paratmers a, c and d are [-0.13647154  0.02557547  0.23301831] for Mn 257.610 treatment number 3
# The fittings paratmers a, c and d are [0.05625604 0.00383191 0.03148316] for Mo 202.032 treatment number 0
# The fittings paratmers a, c and d are [0.06989185 0.00423333 0.02116621] for Mo 202.032 treatment number 1
# The fittings paratmers a, c and d are [0.0511371  0.00788827 0.04011419] for Mo 202.032 treatment number 2
# The fittings paratmers a, c and d are [ 0.10416169  0.00177721 -0.00972379] for Mo 202.032 treatment number 3
# The fittings paratmers a, c and d are [ 2.60791060e-09  8.84231291e-04 -3.78180772e-01] for Na 588.995 treatment number 0
# The fittings paratmers a, c and d are [ 2.60791060e-09  8.84231291e-04 -3.78180772e-01] for Na 588.995 treatment number 1
# The fittings paratmers a, c and d are [ 2.60791060e-09  8.84231291e-04 -3.78180772e-01] for Na 588.995 treatment number 2
# The fittings paratmers a, c and d are [ 2.60791060e-09  8.84231291e-04 -3.78180772e-01] for Na 588.995 treatment number 3
# C:\Users\egillette\Anaconda3\lib\site-packages\scipy\optimize\minpack.py:833: OptimizeWarning: Covariance of the parameters could not be estimated
#   warnings.warn('Covariance of the parameters could not be estimated',
# C:\Users\egillette\Anaconda3\lib\site-packages\scipy\optimize\minpack.py:833: OptimizeWarning: Covariance of the parameters could not be estimated
#   warnings.warn('Covariance of the parameters could not be estimated',
# C:\Users\egillette\Anaconda3\lib\site-packages\scipy\optimize\minpack.py:833: OptimizeWarning: Covariance of the parameters could not be estimated
#   warnings.warn('Covariance of the parameters could not be estimated',
# C:\Users\egillette\Anaconda3\lib\site-packages\scipy\optimize\minpack.py:833: OptimizeWarning: Covariance of the parameters could not be estimated
#   warnings.warn('Covariance of the parameters could not be estimated',
# The fittings paratmers a, c and d are [5.77419415e-09 1.42362240e-03 6.17739085e-01] for Na 589.592 treatment number 0
# The fittings paratmers a, c and d are [ 5.78484796e+03  9.79288053e-07 -5.77998951e+03] for Na 589.592 treatment number 1
# The fittings paratmers a, c and d are [5.77419415e-09 1.42362240e-03 6.17739085e-01] for Na 589.592 treatment number 2
# The fittings paratmers a, c and d are [31.20970345  0.04867166  4.01085377] for Na 589.592 treatment number 3
# C:\Users\egillette\Anaconda3\lib\site-packages\scipy\optimize\minpack.py:833: OptimizeWarning: Covariance of the parameters could not be estimated
#   warnings.warn('Covariance of the parameters could not be estimated',
# C:\Users\egillette\Anaconda3\lib\site-packages\scipy\optimize\minpack.py:833: OptimizeWarning: Covariance of the parameters could not be estimated
#   warnings.warn('Covariance of the parameters could not be estimated',
# The fittings paratmers a, c and d are [-0.00511882  0.07949785  0.09586401] for Ni 231.604 treatment number 0
# The fittings paratmers a, c and d are [-0.00707057  0.00112362  0.10092188] for Ni 231.604 treatment number 1
# The fittings paratmers a, c and d are [-2.30632773e+00  7.87347862e-07  2.40046937e+00] for Ni 231.604 treatment number 2
# The fittings paratmers a, c and d are [-0.00616428  0.00591377  0.09960801] for Ni 231.604 treatment number 3
# The fittings paratmers a, c and d are [0.02621014 0.0051503  0.06190672] for Pb 220.353 treatment number 0
# The fittings paratmers a, c and d are [0.02876636 0.00303355 0.0602201 ] for Pb 220.353 treatment number 1
# The fittings paratmers a, c and d are [0.04082829 0.01480787 0.04926822] for Pb 220.353 treatment number 2
# The fittings paratmers a, c and d are [0.03627151 0.0034559  0.0522114 ] for Pb 220.353 treatment number 3
# The fittings paratmers a, c and d are [ 1.10172481e+02  5.44410089e-07 -1.10077290e+02] for Sb 206.834 treatment number 0
# The fittings paratmers a, c and d are [ 1.12889076e+02  7.30757308e-07 -1.12794392e+02] for Sb 206.834 treatment number 1
# The fittings paratmers a, c and d are [0.02795506 0.00210901 0.06685431] for Sb 206.834 treatment number 2
# The fittings paratmers a, c and d are [ 2.00400473e+02  3.93111440e-07 -2.00305941e+02] for Sb 206.834 treatment number 3
# The fittings paratmers a, c and d are [0.00166812 0.00332877 0.09183704] for Se 196.026 treatment number 0
# The fittings paratmers a, c and d are [-0.0071078   0.00106789  0.0992817 ] for Se 196.026 treatment number 1
# The fittings paratmers a, c and d are [0.00138447 0.01233977 0.09120986] for Se 196.026 treatment number 2
# The fittings paratmers a, c and d are [-0.00107039  0.05634924  0.09222527] for Se 196.026 treatment number 3
# The fittings paratmers a, c and d are [0.02311404 0.0021184  0.06912669] for Th 283.730 treatment number 0
# The fittings paratmers a, c and d are [0.01113925 0.00303955 0.08086047] for Th 283.730 treatment number 1
# The fittings paratmers a, c and d are [0.03038441 0.00591802 0.06068192] for Th 283.730 treatment number 2
# The fittings paratmers a, c and d are [0.00840002 0.0063782  0.08051469] for Th 283.730 treatment number 3
# The fittings paratmers a, c and d are [0.41365345 1.36940673 0.20995234] for Th 288.505 treatment number 0
# The fittings paratmers a, c and d are [0.03969482 0.00640128 0.09261697] for Th 288.505 treatment number 1
# The fittings paratmers a, c and d are [0.03018728 0.00840117 0.06961927] for Th 288.505 treatment number 2
# The fittings paratmers a, c and d are [ 4.29423328e-17 -5.27591202e-02  2.42213418e-01] for Th 288.505 treatment number 3
# The fittings paratmers a, c and d are [0.00080651 0.00532535 0.09283571] for Tl 190.794 treatment number 0
# The fittings paratmers a, c and d are [-0.00382581  0.00471584  0.09501399] for Tl 190.794 treatment number 1
# The fittings paratmers a, c and d are [-1.86063558e+00  7.04886389e-07  1.95115282e+00] for Tl 190.794 treatment number 2
# The fittings paratmers a, c and d are [-0.00133954  0.03051021  0.09199393] for Tl 190.794 treatment number 3
# The fittings paratmers a, c and d are [0.0222578  0.00589361 0.09719115] for Tl 351.923 treatment number 0
# The fittings paratmers a, c and d are [-1.53425915e+01  5.36274592e-07  1.54376467e+01] for Tl 351.923 treatment number 1
# The fittings paratmers a, c and d are [-9.73322412e-06 -7.21138932e-03  9.61315048e-02] for Tl 351.923 treatment number 2
# The fittings paratmers a, c and d are [-6.23640409e+01  4.96204768e-07  6.24647673e+01] for Tl 351.923 treatment number 3
# The fittings paratmers a, c and d are [-0.01174942  0.01086982  0.10623809] for U 385.957 treatment number 0
# The fittings paratmers a, c and d are [-6.52835855e-01  5.26236745e-07  7.50471531e-01] for U 385.957 treatment number 1
# The fittings paratmers a, c and d are [0.01698472 0.01263128 0.08215041] for U 385.957 treatment number 2
# The fittings paratmers a, c and d are [-0.07121092  0.00265513  0.16356327] for U 385.957 treatment number 3
# The fittings paratmers a, c and d are [-9.54745933e-01  7.55580013e-07  1.04861509e+00] for V 292.401 treatment number 0
# The fittings paratmers a, c and d are [-8.45900506e+00  6.07192183e-07  8.55015591e+00] for V 292.401 treatment number 1
# The fittings paratmers a, c and d are [-5.49910826e+00  4.27977107e-07  5.58841609e+00] for V 292.401 treatment number 2
# The fittings paratmers a, c and d are [-1.18202075e+01  7.37885114e-07  1.19114472e+01] for V 292.401 treatment number 3
# The fittings paratmers a, c and d are [0.12172027 0.0038528  0.12295746] for Zn 206.200 treatment number 0
# The fittings paratmers a, c and d are [ 5.82695131e+02 -4.08215680e-07 -5.82452903e+02] for Zn 206.200 treatment number 1
# The fittings paratmers a, c and d are [0.16706031 0.00246689 0.08946429] for Zn 206.200 treatment number 2
# The fittings paratmers a, c and d are [ 3.63080391e+02  3.39469321e-07 -3.62824072e+02] for Zn 206.200 treatment number 3
# The fittings paratmers a, c and d are [0.12272939 0.00385115 0.12071216] for Zn 213.857 treatment number 0
# The fittings paratmers a, c and d are [ 5.38900705e+02 -4.45043207e-07 -5.38660653e+02] for Zn 213.857 treatment number 1
# The fittings paratmers a, c and d are [0.16652478 0.00249869 0.0877342 ] for Zn 213.857 treatment number 2
# The fittings paratmers a, c and d are [ 3.44023315e+02  3.51883878e-07 -3.43768867e+02] for Zn 213.857 treatment number 3
